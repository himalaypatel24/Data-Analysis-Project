# %%
import pandas as pd

# %%
weather=pd.read_csv('1. Weather Data.csv')

# %%
weather.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
weather.shape
# Out:
# (8784, 8)

# %%
weather.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
weather.columns=['Date_Time','Temp','Dew_Point','Humidity','Wind_Speed','Visibility','Pressure','Weather']

# %%
weather
# Out:
#              Date_Time  Temp  Dew_Point  Humidity  Wind_Speed  Visibility  \
# 0        1/1/2012 0:00  -1.8       -3.9        86           4         8.0
# 1        1/1/2012 1:00  -1.8       -3.7        87           4         8.0
# 2        1/1/2012 2:00  -1.8       -3.4        89           7         4.0
# 3        1/1/2012 3:00  -1.5       -3.2        88           6         4.0
# 4        1/1/2012 4:00  -1.5       -3.3        88           7         4.8
# ...                ...   ...        ...       ...         ...         ...
# 8779  12/31/2012 19:00   0.1       -2.7        81          30         9.7
# 8780  12/31/2012 20:00   0.2       -2.4        83          24         9.7
# 8781  12/31/2012 21:00  -0.5       -1.5        93          28         4.8
# 8782  12/31/2012 22:00  -0.2       -1.8        89          28         9.7
# 8783  12/31/2012 23:00   0.0       -2.1        86          30        11.3
#
#       Pressure               Weather
# 0       101.24                   Fog
# ...

# %% [markdown]
# ### Q. 1)  Find all the unique 'Wind Speed' values in the data.

# %%
Unique_Values=list(weather['Wind_Speed'].unique())
Unique_Values
# Out:
# [4,
#  7,
#  6,
#  9,
#  15,
#  13,
#  20,
#  22,
#  19,
#  24,
#  30,
#  35,
#  39,
#  32,
#  33,
#  26,
#  44,
#  43,
#  48,
#  37,
#  28,
#  17,
#  11,
#  0,
#  83,
#  70,
#  57,
#  46,
#  41,
#  52,
#  50,
#  63,
#  54,
#  2]

# %% [markdown]
#  ### Find the number of times when the 'Weather is exactly Clear.

# %%
weather['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# ### Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
df=weather[weather['Wind_Speed']==4]
df['Wind_Speed'].value_counts()
# Out:
# 4    474
# Name: Wind_Speed, dtype: int64

# %% [markdown]
# ### Q. 4) Find out all the Null Values in the data.

# %%
weather.isnull().sum()
# Out:
# Date_Time     0
# Temp          0
# Dew_Point     0
# Humidity      0
# Wind_Speed    0
# Visibility    0
# Pressure      0
# Weather       0
# dtype: int64

# %% [markdown]
# ### Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
weather=weather.rename(columns={'Weather':'Weather_Condition'})

# %% [markdown]
# ### Q. 6) What is the mean 'Visibility' ?

# %%
weather.Visibility.mean()
# Out:
# 27.66444672131151

# %% [markdown]
# ### Q. 7) What is the Standard Deviation of 'Pressure'  in this data?

# %%
weather.Pressure.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# ### Q. 8) Find all instances when 'Snow' was recorded.

# %%
weather[weather['Weather_Condition']=='Snow']
# Out:
#              Date_Time  Temp  Dew_Point  Humidity  Wind_Speed  Visibility  \
# 55       1/3/2012 7:00 -14.0      -19.5        63          19        25.0
# 84      1/4/2012 12:00 -13.7      -21.7        51          11        24.1
# 86      1/4/2012 14:00 -11.3      -19.0        53           7        19.3
# 87      1/4/2012 15:00 -10.2      -16.3        61          11         9.7
# 88      1/4/2012 16:00  -9.4      -15.5        61          13        19.3
# ...                ...   ...        ...       ...         ...         ...
# 8779  12/31/2012 19:00   0.1       -2.7        81          30         9.7
# 8780  12/31/2012 20:00   0.2       -2.4        83          24         9.7
# 8781  12/31/2012 21:00  -0.5       -1.5        93          28         4.8
# 8782  12/31/2012 22:00  -0.2       -1.8        89          28         9.7
# 8783  12/31/2012 23:00   0.0       -2.1        86          30        11.3
#
#       Pressure Weather_Condition
# 55      100.95              Snow
# ...

# %% [markdown]
# ### Q. 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
weather[(weather['Wind_Speed']>24) & (weather['Visibility']==25)]
# Out:
#              Date_Time  Temp  Dew_Point  Humidity  Wind_Speed  Visibility  \
# 23      1/1/2012 23:00   5.3        2.0        79          30        25.0
# 24       1/2/2012 0:00   5.2        1.5        77          35        25.0
# 25       1/2/2012 1:00   4.6        0.0        72          39        25.0
# 26       1/2/2012 2:00   3.9       -0.9        71          32        25.0
# 27       1/2/2012 3:00   3.7       -1.5        69          33        25.0
# ...                ...   ...        ...       ...         ...         ...
# 8705  12/28/2012 17:00  -8.6      -12.0        76          26        25.0
# 8753  12/30/2012 17:00 -12.1      -15.8        74          28        25.0
# 8755  12/30/2012 19:00 -13.4      -16.5        77          26        25.0
# 8759  12/30/2012 23:00 -12.1      -15.1        78          28        25.0
# 8760   12/31/2012 0:00 -11.1      -14.4        77          26        25.0
#
#       Pressure Weather_Condition
# 23       99.31            Cloudy
# ...

# %% [markdown]
# ### Q. 11) What is the Mean value of each column against each 'Weather Condition ?

# %%
weather.groupby(['Weather_Condition']).mean().head()
# Out:
#                              Temp  Dew_Point   Humidity  Wind_Speed  \
# Weather_Condition
# Clear                    6.825716   0.089367  64.497738   10.557315
# Cloudy                   7.970544   2.375810  69.592593   16.127315
# Drizzle                  7.353659   5.504878  88.243902   16.097561
# Drizzle,Fog              8.067500   7.033750  93.275000   11.862500
# Drizzle,Ice Pellets,Fog  0.400000  -0.700000  92.000000   20.000000
#
#                          Visibility    Pressure
# Weather_Condition
# Clear                     30.153243  101.587443
# Cloudy                    26.625752  100.911441
# Drizzle                   17.931707  100.435366
# Drizzle,Fog                5.257500  100.786625
# Drizzle,Ice Pellets,Fog    4.000000  100.790000

# %% [markdown]
# ### Q. 12) What is the Minimum & Maximum value of each column against each 'Weather Condition?

# %%
weather.groupby(['Weather_Condition']).agg(['min','max']).head()
# Out:
#                                Date_Time                   Temp        \
#                                      min              max   min   max
# Weather_Condition
# Clear                     1/11/2012 1:00    9/9/2012 5:00 -23.3  32.8
# Cloudy                    1/1/2012 17:00   9/9/2012 23:00 -21.4  30.5
# Drizzle                  1/23/2012 21:00   9/30/2012 3:00   1.1  18.8
# Drizzle,Fog              1/23/2012 20:00   9/30/2012 2:00   0.0  19.9
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00  12/17/2012 9:00   0.4   0.4
#
#                         Dew_Point       Humidity      Wind_Speed      \
#                               min   max      min  max        min max
# Weather_Condition
# Clear                       -28.5  20.4       20   99          0  33
# Cloudy                      -26.8  22.6       18   99          0  54
# Drizzle                      -0.2  17.7       74   96          0  30
# Drizzle,Fog                  -1.6  19.1       85  100          0  28
# ...

# %% [markdown]
# ### Q. 15) Find all instances when :
# ### A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# ### or
#  ### B. 'Visibility is above 40'

# %%
weather[(weather['Weather_Condition']=='Clear') & (weather['Humidity']>50) | (weather['Visibility']>40)]
# Out:
#              Date_Time  Temp  Dew_Point  Humidity  Wind_Speed  Visibility  \
# 106     1/5/2012 10:00  -6.0      -10.0        73          17        48.3
# 107     1/5/2012 11:00  -5.6      -10.2        70          22        48.3
# 108     1/5/2012 12:00  -4.7       -9.6        69          20        48.3
# 109     1/5/2012 13:00  -4.4       -9.7        66          26        48.3
# 110     1/5/2012 14:00  -5.1      -10.7        65          22        48.3
# ...                ...   ...        ...       ...         ...         ...
# 8749  12/30/2012 13:00 -12.4      -16.2        73          37        48.3
# 8750  12/30/2012 14:00 -11.8      -16.1        70          37        48.3
# 8751  12/30/2012 15:00 -11.3      -15.6        70          32        48.3
# 8752  12/30/2012 16:00 -11.4      -15.5        72          26        48.3
# 8756  12/30/2012 20:00 -13.8      -16.5        80          24        25.0
#
#       Pressure Weather_Condition
# 106     100.45      Mainly Clear
# ...
